# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import asapy
import numpy as np

# %% [markdown]
# # Cenário: Demonstração de Navegação com Aeronave de Caça
#
# ### Descrição Geral:
# Este cenário descreve um voo de navegação realizado por uma aeronave de caça, enfocando a execução de manobras em diferentes altitudes e velocidades. A navegação abrange uma variação de altitude entre Flight Level (FL) 100 e FL 350, bem como uma variação de velocidade entre 350 knots e 550 knots. Durante este voo, no terceiro ponto da rota, a aeronave realizará uma manobra de espera em torno de um ponto específico (**Hold**) durante 10 minutos, integrando-a ao padrão de voo.
#
# <img src='./nav_demo.gif' width='500' height='500'>

# %% [markdown]
# #### Carregando Dados das Simulações
#
# Nesta célula, estamos carregando dados de diferentes simulações a partir de arquivos CSV. Para cada cenário, existem dois tipos de arquivos:
#
# 1. Arquivos `*_aliases.csv`: Estes contêm as entradas (ou parâmetros) para cada simulação.
#
# 2. Arquivos `*_output.csv`: Estes contêm os resultados das simulações.
#
# Os dados são lidos e carregados em DataFrames do pandas para análise e processamento subsequentes.

# %%
x = pd.read_csv('./nav_demo_aliases.csv')
y = pd.read_csv('./nav_demo_output.csv')

# %%
preprocessing  = asapy.Preprocessing()

x = preprocessing.aliases(x)
y = preprocessing.team_metrics(y)

# %%
df_nav = pd.merge(x, y[['fuel_consumed']], left_index=True, right_index=True)

# %%
sample_nav = df_nav.sample(10)
df_nav = df_nav.loc[~df_nav.index.isin(sample_nav.index)]

# %%
df_nav.head(5)
# Out:
#              speed  altitude  fuel_consumed
# experiment
# 0           485.10  13339.30    1460.593196
# 1           518.46  34516.34     883.070714
# 2           501.61  23487.75    1063.105283
# 3           525.65  16748.43    1400.689116
# 4           438.32  21489.87    1051.047824

# %% [markdown]
# ## EXPERIMENTO 1: Previsão do Consumo de Combustível na rota específica
#
# ### Objetivo do Experimento:
# Este experimento visa investigar a relação entre o tempo de voo (`time_of_flight_blue`) e o consumo de combustível (`fuel_consumed_blue`) em um cenário de simulação de voo. O objetivo principal é entender se existe uma correlação direta entre essas duas variáveis, ou seja, se um aumento no tempo de voo resulta consistentemente em um maior consumo de combustível.
#
# ### Metodologia:
# - Dados Utilizados: Serão analisados dados de **4000** simulações de voo, onde `time_of_flight_blue` representa a duração total do voo (em segundos) e `fuel_consumed_blue` indica a quantidade de combustível consumida (em libras).
# - Análise Estatística: Aplicar métodos estatísticos para avaliar a relação entre as duas variáveis. Isso inclue a realização de uma análise de regressão linear, cálculo do coeficiente de correlação, ou outros métodos estatísticos relevantes.
# - Visualização de Dados: Utilizar gráficos (como gráficos de dispersão) para visualizar a relação entre tempo de voo e consumo de combustível, facilitando a interpretação dos resultados.
#
# ### Hipóteses:
# A hipótese principal é que existe uma correlação positiva entre o tempo de voo e o consumo de combustível, significando que quanto maior o tempo de voo, maior o consumo de combustível.
#
# ### Resultados Esperados:
# Os resultados podem ser úteis para o planejamento de rotas aéreas mais eficientes em termos de consumo de combustível, e para aprimorar modelos de previsão de consumo de combustível em simulações aeronáuticas.
#
# ### Aplicações Potenciais:
# Os resultados podem ser úteis para treinamento em simuladores de voo, planejamento de rotas aéreas mais eficientes em termos de combustível, e para aprimorar modelos de previsão de consumo de combustível em simulações aeronáuticas.

# %% [markdown]
# #### Rede Neural

# %%
nn_nav = asapy.NeuralNetwork(target="fuel_consumed", name='demo_nn_nav', seed=25)

# %%
nn_nav.build(
    df_nav,
    task="regression",
    max_cat_nunique = 10,
    split_size = (0.7, 0.15, 0.15),
    info=True,
    patience_early_stopping = 20,
    patience_reduceLR = 4,
    metrics=['rmse', 'mae']
)
# Out:
#                 Task: regression
#
#                 Total of registers: 3990
#                 Total of valid registers: 3990
#                 Total of invalid registers: 0
#
#                 Total of training registers: 2792
#                 Total of validation registers: 599
#                 Total of test registers: 599
#
#                 Features before preprocessing: 2
#                 Features after preprocessing: 2
#
#                 Numerical Features: ['speed', 'altitude']
#                 Categorical Features: []
#                 Categorical Features removed due to high cardinality: []
#
#                 Target: ['fuel_consumed']

# %%
nn_nav.hyperparameter_optimization(
    n_trials=18,
    num_folds=4,
    info=True,
    search_space_dropout = [0.0, 0.5],
    search_space_layers = [2, 3, 4],
    search_space_batch_size = [32, 64, 128],
    search_space_optimizer = ['Adam']
)
# Out:
# <style type="text/css">
# #T_2ce3f th {
#   text-align: center;
# }
# </style>
# <table id="T_2ce3f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ce3f_level0_col0" class="col_heading level0 col0" colspan="7">Mean Squared Error</th>
#       <th id="T_2ce3f_level0_col7" class="col_heading level0 col7" colspan="4">Hyperparameters</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_2ce3f_level1_col0" class="col_heading level1 col0" >Trial (nº)</th>
#       <th id="T_2ce3f_level1_col1" class="col_heading level1 col1" >Fold nº 1</th>
#       <th id="T_2ce3f_level1_col2" class="col_heading level1 col2" >Fold nº 2</th>
#       <th id="T_2ce3f_level1_col3" class="col_heading level1 col3" >Fold nº 3</th>
#       <th id="T_2ce3f_level1_col4" class="col_heading level1 col4" >Fold nº 4</th>
#       <th id="T_2ce3f_level1_col5" class="col_heading level1 col5" >Folds std</th>
#       <th id="T_2ce3f_level1_col6" class="col_heading level1 col6" >Folds mean</th>
#       <th id="T_2ce3f_level1_col7" class="col_heading level1 col7" >params_batch_size</th>
#       <th id="T_2ce3f_level1_col8" class="col_heading level1 col8" >params_dropout</th>
#       <th id="T_2ce3f_level1_col9" class="col_heading level1 col9" >params_layers</th>
#       <th id="T_2ce3f_level1_col10" class="col_heading level1 col10" >params_optimizer</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranking</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ce3f_level0_row0" class="row_heading level0 row0" >1º</th>
#       <td id="T_2ce3f_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_2ce3f_row0_col1" class="data row0 col1" >0.028622</td>
#       <td id="T_2ce3f_row0_col2" class="data row0 col2" >0.059739</td>
#       <td id="T_2ce3f_row0_col3" class="data row0 col3" >0.076093</td>
#       <td id="T_2ce3f_row0_col4" class="data row0 col4" >0.058316</td>
#       <td id="T_2ce3f_row0_col5" class="data row0 col5" >0.019767</td>
#       <td id="T_2ce3f_row0_col6" class="data row0 col6" >0.055692</td>
#       <td id="T_2ce3f_row0_col7" class="data row0 col7" >64</td>
#       <td id="T_2ce3f_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_2ce3f_row0_col9" class="data row0 col9" >4</td>
#       <td id="T_2ce3f_row0_col10" class="data row0 col10" >Adam</td>
#     </tr>
#     <tr>
#       <th id="T_2ce3f_level0_row1" class="row_heading level0 row1" >2º</th>
#       <td id="T_2ce3f_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_2ce3f_row1_col1" class="data row1 col1" >0.067284</td>
#       <td id="T_2ce3f_row1_col2" class="data row1 col2" >0.074975</td>
#       <td id="T_2ce3f_row1_col3" class="data row1 col3" >0.053843</td>
#       <td id="T_2ce3f_row1_col4" class="data row1 col4" >0.062569</td>
#       <td id="T_2ce3f_row1_col5" class="data row1 col5" >0.008844</td>
#       <td id="T_2ce3f_row1_col6" class="data row1 col6" >0.064668</td>
#       <td id="T_2ce3f_row1_col7" class="data row1 col7" >128</td>
#       <td id="T_2ce3f_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_2ce3f_row1_col9" class="data row1 col9" >3</td>
#       <td id="T_2ce3f_row1_col10" class="data row1 col10" >Adam</td>
#     </tr>
#     <tr>
#       <th id="T_2ce3f_level0_row2" class="row_heading level0 row2" >3º</th>
#       <td id="T_2ce3f_row2_col0" class="data row2 col0" >11</td>
#       <td id="T_2ce3f_row2_col1" class="data row2 col1" >0.060589</td>
#       <td id="T_2ce3f_row2_col2" class="data row2 col2" >0.051538</td>
#       <td id="T_2ce3f_row2_col3" class="data row2 col3" >0.138791</td>
#       <td id="T_2ce3f_row2_col4" class="data row2 col4" >0.053904</td>
#       <td id="T_2ce3f_row2_col5" class="data row2 col5" >0.041899</td>
#       <td id="T_2ce3f_row2_col6" class="data row2 col6" >0.076206</td>
#       <td id="T_2ce3f_row2_col7" class="data row2 col7" >128</td>
#       <td id="T_2ce3f_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_2ce3f_row2_col9" class="data row2 col9" >4</td>
#       <td id="T_2ce3f_row2_col10" class="data row2 col10" >Adam</td>
#     </tr>
#     <tr>
#       <th id="T_2ce3f_level0_row3" class="row_heading level0 row3" >4º</th>
#       <td id="T_2ce3f_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_2ce3f_row3_col1" class="data row3 col1" >0.096393</td>
#       <td id="T_2ce3f_row3_col2" class="data row3 col2" >0.079980</td>
#       <td id="T_2ce3f_row3_col3" class="data row3 col3" >0.072342</td>
#       <td id="T_2ce3f_row3_col4" class="data row3 col4" >0.062905</td>
#       <td id="T_2ce3f_row3_col5" class="data row3 col5" >0.014166</td>
#       <td id="T_2ce3f_row3_col6" class="data row3 col6" >0.077905</td>
#       <td id="T_2ce3f_row3_col7" class="data row3 col7" >64</td>
#       <td id="T_2ce3f_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_2ce3f_row3_col9" class="data row3 col9" >3</td>
#       <td id="T_2ce3f_row3_col10" class="data row3 col10" >Adam</td>
#     </tr>
#     <tr>
#       <th id="T_2ce3f_level0_row4" class="row_heading level0 row4" >5º</th>
#       <td id="T_2ce3f_row4_col0" class="data row4 col0" >10</td>
#       <td id="T_2ce3f_row4_col1" class="data row4 col1" >0.092860</td>
#       <td id="T_2ce3f_row4_col2" class="data row4 col2" >0.037649</td>
#       <td id="T_2ce3f_row4_col3" class="data row4 col3" >0.077952</td>
#       <td id="T_2ce3f_row4_col4" class="data row4 col4" >0.103603</td>
#       <td id="T_2ce3f_row4_col5" class="data row4 col5" >0.028893</td>
#       <td id="T_2ce3f_row4_col6" class="data row4 col6" >0.078016</td>
#       <td id="T_2ce3f_row4_col7" class="data row4 col7" >64</td>
#       <td id="T_2ce3f_row4_col8" class="data row4 col8" >0.000000</td>
#       <td id="T_2ce3f_row4_col9" class="data row4 col9" >4</td>
#       <td id="T_2ce3f_row4_col10" class="data row4 col10" >Adam</td>
#     </tr>
#     <tr>
#       <th id="T_2ce3f_level0_row5" class="row_heading level0 row5" >6º</th>
#       <td id="T_2ce3f_row5_col0" class="data row5 col0" >8</td>
#       <td id="T_2ce3f_row5_col1" class="data row5 col1" >0.089823</td>
#       <td id="T_2ce3f_row5_col2" class="data row5 col2" >0.056763</td>
#       <td id="T_2ce3f_row5_col3" class="data row5 col3" >0.104702</td>
#       <td id="T_2ce3f_row5_col4" class="data row5 col4" >0.062356</td>
#       <td id="T_2ce3f_row5_col5" class="data row5 col5" >0.022715</td>
#       <td id="T_2ce3f_row5_col6" class="data row5 col6" >0.078411</td>
#       <td id="T_2ce3f_row5_col7" class="data row5 col7" >64</td>
#       <td id="T_2ce3f_row5_col8" class="data row5 col8" >0.000000</td>
#       <td id="T_2ce3f_row5_col9" class="data row5 col9" >2</td>
#       <td id="T_2ce3f_row5_col10" class="data row5 col10" >Adam</td>
#     </tr>
#     <tr>
#       <th id="T_2ce3f_level0_row6" class="row_heading level0 row6" >7º</th>
#       <td id="T_2ce3f_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_2ce3f_row6_col1" class="data row6 col1" >0.109638</td>
#       <td id="T_2ce3f_row6_col2" class="data row6 col2" >0.069981</td>
#       <td id="T_2ce3f_row6_col3" class="data row6 col3" >0.071074</td>
#       <td id="T_2ce3f_row6_col4" class="data row6 col4" >0.065267</td>
#       <td id="T_2ce3f_row6_col5" class="data row6 col5" >0.020587</td>
#       <td id="T_2ce3f_row6_col6" class="data row6 col6" >0.078990</td>
#       <td id="T_2ce3f_row6_col7" class="data row6 col7" >32</td>
#       <td id="T_2ce3f_row6_col8" class="data row6 col8" >0.000000</td>
#       <td id="T_2ce3f_row6_col9" class="data row6 col9" >3</td>
#       <td id="T_2ce3f_row6_col10" class="data row6 col10" >Adam</td>
#     </tr>
#     <tr>
#       <th id="T_2ce3f_level0_row7" class="row_heading level0 row7" >8º</th>
#       <t

# %%
nn_nav.fit(return_history=False, graph=True, graph_save_extension='png', verbose=0)

# %%
pred_nn_nav = nn_nav.predict(sample_nav, verbose=0)
# Out:
# Inference time: 54.00 milliseconds (10 register(s))

# %%
pred_nn_nav
# Out:
#              speed  altitude  fuel_consumed  fuel_consumed (NN prediction)
# experiment
# 3266        490.79  21023.50    1115.229005                    1208.326660
# 899         417.70  19493.63    1045.098811                    1013.864807
# 2688        548.68  18091.96    1432.336869                    1504.851807
# 759         543.28  27516.24    1029.590081                     967.180542
# 3831        370.45  14208.57    1111.765185                    1146.273804
# 492         472.37  13728.88    1393.019961                    1504.851807
# 685         537.91  28614.80     981.147124                     967.180542
# 3950        353.04  20240.53    1077.057356                    1042.824463
# 372         538.80  24256.56    1131.559975                    1208.326660
# 3644        475.60  13993.67    1393.584303                    1504.851807

# %% [markdown]
# #### XG Boost

# %%
xgb_nav = asapy.XgBoost(target="fuel_consumed", name='demo_xgb_nav', seed=25)

# %%
xgb_nav.build(
    df_nav,
    task="regression",
    num_folds=5,
    max_cat_nunique = 10,
    split_size = (0.7, 0.15, 0.15),
    info=True,
    patience_early_stopping = 20,
    metrics=['rmse', 'mae']
)
# Out:
#                 Task: regression
#
#                 Total of registers: 3990
#                 Total of valid registers: 3990
#                 Total of invalid registers: 0
#
#                 Total of training registers: 2792
#                 Total of validation registers: 599
#                 Total of test registers: 599
#
#                 Features before preprocessing: 2
#                 Features after preprocessing: 2
#
#                 Numerical Features: ['speed', 'altitude']
#                 Categorical Features: []
#                 Categorical Features removed due to high cardinality: []
#
#                 Target: ['fuel_consumed']

# %%
xgb_nav.hyperparameter_optimization(
    n_trials=10,
    num_folds = 5, 
    info=True,
    search_space_tree_method = ['auto'],
    search_space_booster = ['gbtree', 'gblinear', 'dart'],
    search_space_learning_rate = [0.3],
    search_space_min_split_loss = [0],
    search_space_max_depth = [6],
    search_space_min_child_weight = [1],
    search_space_max_delta_step = [0],
    search_space_subsample = [1],
    search_space_sampling_method = ['uniform'],
    search_space_colsample_bytree = [1],
    search_space_colsample_bylevel = [1],
    search_space_colsample_bynode = [1],
    search_space_reg_lambda = [1],
    search_space_reg_alpha = [0],
    search_space_scale_pos_weight = [1],
    search_space_grow_policy = ['depthwise'],
    search_space_max_leaves = [0],
    search_space_max_bin = [256],
    search_space_num_parallel_tree = [1]
)
# Out:
# <style type="text/css">
# #T_a330e th {
#   text-align: center;
# }
# </style>
# <table id="T_a330e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a330e_level0_col0" class="col_heading level0 col0" colspan="8">Mean Squared Error</th>
#       <th id="T_a330e_level0_col8" class="col_heading level0 col8" colspan="19">Hyperparameters</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_a330e_level1_col0" class="col_heading level1 col0" >Trial (nº)</th>
#       <th id="T_a330e_level1_col1" class="col_heading level1 col1" >Fold nº 1</th>
#       <th id="T_a330e_level1_col2" class="col_heading level1 col2" >Fold nº 2</th>
#       <th id="T_a330e_level1_col3" class="col_heading level1 col3" >Fold nº 3</th>
#       <th id="T_a330e_level1_col4" class="col_heading level1 col4" >Fold nº 4</th>
#       <th id="T_a330e_level1_col5" class="col_heading level1 col5" >Fold nº 5</th>
#       <th id="T_a330e_level1_col6" class="col_heading level1 col6" >Folds std</th>
#       <th id="T_a330e_level1_col7" class="col_heading level1 col7" >Folds mean</th>
#       <th id="T_a330e_level1_col8" class="col_heading level1 col8" >params_booster</th>
#       <th id="T_a330e_level1_col9" class="col_heading level1 col9" >params_colsample_bylevel</th>
#       <th id="T_a330e_level1_col10" class="col_heading level1 col10" >params_colsample_bynode</th>
#       <th id="T_a330e_level1_col11" class="col_heading level1 col11" >params_colsample_bytree</th>
#       <th id="T_a330e_level1_col12" class="col_heading level1 col12" >params_grow_policy</th>
#       <th id="T_a330e_level1_col13" class="col_heading level1 col13" >params_learning_rate</th>
#       <th id="T_a330e_level1_col14" class="col_heading level1 col14" >params_max_bin</th>
#       <th id="T_a330e_level1_col15" class="col_heading level1 col15" >params_max_delta_step</th>
#       <th id="T_a330e_level1_col16" class="col_heading level1 col16" >params_max_depth</th>
#       <th id="T_a330e_level1_col17" class="col_heading level1 col17" >params_max_leaves</th>
#       <th id="T_a330e_level1_col18" class="col_heading level1 col18" >params_min_child_weight</th>
#       <th id="T_a330e_level1_col19" class="col_heading level1 col19" >params_min_split_loss</th>
#       <th id="T_a330e_level1_col20" class="col_heading level1 col20" >params_num_parallel_tree</th>
#       <th id="T_a330e_level1_col21" class="col_heading level1 col21" >params_reg_alpha</th>
#       <th id="T_a330e_level1_col22" class="col_heading level1 col22" >params_reg_lambda</th>
#       <th id="T_a330e_level1_col23" class="col_heading level1 col23" >params_sampling_method</th>
#       <th id="T_a330e_level1_col24" class="col_heading level1 col24" >params_scale_pos_weight</th>
#       <th id="T_a330e_level1_col25" class="col_heading level1 col25" >params_subsample</th>
#       <th id="T_a330e_level1_col26" class="col_heading level1 col26" >params_tree_method</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranking</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a330e_level0_row0" class="row_heading level0 row0" >1º</th>
#       <td id="T_a330e_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_a330e_row0_col1" class="data row0 col1" >0.031205</td>
#       <td id="T_a330e_row0_col2" class="data row0 col2" >0.033241</td>
#       <td id="T_a330e_row0_col3" class="data row0 col3" >0.032306</td>
#       <td id="T_a330e_row0_col4" class="data row0 col4" >0.034317</td>
#       <td id="T_a330e_row0_col5" class="data row0 col5" >0.030183</td>
#       <td id="T_a330e_row0_col6" class="data row0 col6" >0.001629</td>
#       <td id="T_a330e_row0_col7" class="data row0 col7" >0.032251</td>
#       <td id="T_a330e_row0_col8" class="data row0 col8" >gbtree</td>
#       <td id="T_a330e_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_a330e_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_a330e_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_a330e_row0_col12" class="data row0 col12" >depthwise</td>
#       <td id="T_a330e_row0_col13" class="data row0 col13" >0.300000</td>
#       <td id="T_a330e_row0_col14" class="data row0 col14" >256</td>
#       <td id="T_a330e_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_a330e_row0_col16" class="data row0 col16" >6</td>
#       <td id="T_a330e_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_a330e_row0_col18" class="data row0 col18" >1</td>
#       <td id="T_a330e_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_a330e_row0_col20" class="data row0 col20" >1</td>
#       <td id="T_a330e_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_a330e_row0_col22" class="data row0 col22" >1</td>
#       <td id="T_a330e_row0_col23" class="data row0 col23" >uniform</td>
#       <td id="T_a330e_row0_col24" class="data row0 col24" >1</td>
#       <td id="T_a330e_row0_col25" class="data row0 col25" >1</td>
#       <td id="T_a330e_row0_col26" class="data row0 col26" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_a330e_level0_row1" class="row_heading level0 row1" >2º</th>
#       <td id="T_a330e_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_a330e_row1_col1" class="data row1 col1" >0.035544</td>
#       <td id="T_a330e_row1_col2" class="data row1 col2" >0.032869</td>
#       <td id="T_a330e_row1_col3" class="data row1 col3" >0.033579</td>
#       <td id="T_a330e_row1_col4" class="data row1 col4" >0.029681</td>
#       <td id="T_a330e_row1_col5" class="data row1 col5" >0.035415</td>
#       <td id="T_a330e_row1_col6" class="data row1 col6" >0.002388</td>
#       <td id="T_a330e_row1_col7" class="data row1 col7" >0.033418</td>
#       <td id="T_a330e_row1_col8" class="data row1 col8" >gbtree</td>
#       <td id="T_a330e_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_a330e_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_a330e_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_a330e_row1_col12" class="data row1 col12" >depthwise</td>
#       <td id="T_a330e_row1_col13" class="data row1 col13" >0.300000</td>
#       <td id="T_a330e_row1_col14" class="data row1 col14" >256</td>
#       <td id="T_a330e_row1_col15" class="data row1 col15" >0</td>
#       <td id="T_a330e_row1_col16" class="data row1 col16" >6</td>
#       <td id="T_a330e_row1_col17" class="data row1 col17" >0</td>
#       <td id="T_a330e_row1_col18" class="data row1 col18" >1</td>
#       <td id="T_a330e_row1_col19" class="data row1 col19" >0</td>
#       <td id="T_a330e_row1_col20" class="data row1 col20" >1</td>
#       <td id="T_a330e_row1_col21" class="data row1 col21" >0</td>
#       <td id="T_a330e_row1_col22" class="data row1 col22" >1</td>
#       <td id="T_a330e_row1_col23" class="data row1 col23" >uniform</td>
#       <td id="T_a330e_row1_col24" class="data row1 col24" >1</td>
#       <td id="T_a330e_row1_col25" class="data row1 col25" >1</td>
#       <td id="T_a330e_row1_col26" class="data row1 col26

# %%
history_xgb_nav = xgb_nav.fit(return_history=True, graph=True, graph_save_extension='png', verbose=0)

# %%
pred_xgb_nav = xgb_nav.predict(sample_nav)
# Out:
# Inference time: 6.28 milliseconds (10 register(s))

# %%
pred_xgb_nav
# Out:
#              speed  altitude  fuel_consumed  fuel_consumed (XGB prediction)
# experiment
# 3266        490.79  21023.50    1115.229005                     1114.041016
# 899         417.70  19493.63    1045.098811                     1045.191040
# 2688        548.68  18091.96    1432.336869                     1430.138794
# 759         543.28  27516.24    1029.590081                     1027.876221
# 3831        370.45  14208.57    1111.765185                     1111.015869
# 492         472.37  13728.88    1393.019961                     1401.184814
# 685         537.91  28614.80     981.147124                      981.832275
# 3950        353.04  20240.53    1077.057356                     1084.932251
# 372         538.80  24256.56    1131.559975                     1140.322998
# 3644        475.60  13993.67    1393.584303                     1391.689209

# %% [markdown]
# ## EXPERIMENTO 2: Previsão do Consumo de Combustível na rota específica
#
# ### Objetivo do Experimento:
# Este experimento visa investigar a relação entre o tempo de voo (`time_of_flight_blue`) e o consumo de combustível (`fuel_consumed_blue`) em um cenário de simulação de voo. O objetivo principal é entender se existe uma correlação direta entre essas duas variáveis, ou seja, se um aumento no tempo de voo resulta consistentemente em um maior consumo de combustível.
#
# ### Metodologia:
# - Dados Utilizados: Serão analisados dados de **4000** simulações de voo, onde `time_of_flight_blue` representa a duração total do voo (em segundos) e `fuel_consumed_blue` indica a quantidade de combustível consumida (em libras).
# - Análise Estatística: Aplicar métodos estatísticos para avaliar a relação entre as duas variáveis. Isso inclue a realização de uma análise de regressão linear, cálculo do coeficiente de correlação, ou outros métodos estatísticos relevantes.
# - Visualização de Dados: Utilizar gráficos (como gráficos de dispersão) para visualizar a relação entre tempo de voo e consumo de combustível, facilitando a interpretação dos resultados.
#
# ### Hipóteses:
# A hipótese principal é que existe uma correlação positiva entre o tempo de voo e o consumo de combustível, significando que quanto maior o tempo de voo, maior o consumo de combustível.
#
# ### Resultados Esperados:
# Os resultados podem ser úteis para o planejamento de rotas aéreas mais eficientes em termos de consumo de combustível, e para aprimorar modelos de previsão de consumo de combustível em simulações aeronáuticas.
#
# ### Aplicações Potenciais:
# Os resultados podem ser úteis para treinamento em simuladores de voo, planejamento de rotas aéreas mais eficientes em termos de combustível, e para aprimorar modelos de previsão de consumo de combustível em simulações aeronáuticas.

# %% [markdown]
# #### KMeans

# %%
kmeans_nav = asapy.KMeans(name='demo_kmeans_nav', seed=25)

# %%
kmeans_nav.build(df_nav, info=True)
# Out:
#                 Total of registers: 3990
#                 Total of valid registers: 3990
#                 Total of invalid registers: 0
#
#                 Total of Features: 3
#                 Numerical Features: ['speed', 'altitude', 'fuel_consumed']
#                 Categorical Features: []
#                 Categorical Features removed due to high cardinality: []

# %%
kmeans_nav.hyperparameter_optimization(
    n_trials=10,
    info=True,
    search_space_n_clusters=[4],
    search_space_init  = ['k-means++'],
    search_space_n_init = ['auto'],
    search_space_tol = [1e-5, 1e-4, 1e-3],
    search_space_algorithm = ['lloyd', 'elkan']
)
# Out:
#          Trial (nº)  Silhouette Score params_algorithm params_init  \
# Ranking
# 1º                3          0.394695            elkan   k-means++
# 2º                4          0.394695            elkan   k-means++
# 3º                5          0.394695            elkan   k-means++
# 4º                7          0.394695            elkan   k-means++
# 5º                9          0.394695            lloyd   k-means++
# 6º                0          0.394590            lloyd   k-means++
# 7º                1          0.394464            elkan   k-means++
# 8º                2          0.394464            elkan   k-means++
# 9º                6          0.394464            lloyd   k-means++
# 10º               8          0.394464            elkan   k-means++
#
#          params_n_clusters params_n_init  params_tol
# Ranking
# 1º                       4          auto     0.00001
# 2º                       4          auto     0.00001
# 3º                       4          auto     0.00001
# 4º                       4          auto     0.00001
# 5º                       4          auto     0.00001
# 6º                       4          auto     0.00010
# 7º                       4          auto     0.00100
# 8º                       4          auto     0.00100
# 9º                       4          auto     0.00100
# 10º                      4          auto     0.00100

# %%
clusters = kmeans_nav.fit(return_cluster=True)

# %%
kmeans_nav.predict(projection='2d', graph_save_extension='png')

# %%
kmeans_nav.predict(projection='3d', graph_save_extension='png')

# %% [markdown]
# ## EXPERIMENTO 3: Previsão do Consumo de Combustível na rota específica
#
# ### Objetivo do Experimento:
# Este experimento visa investigar a relação entre o tempo de voo (`time_of_flight_blue`) e o consumo de combustível (`fuel_consumed_blue`) em um cenário de simulação de voo. O objetivo principal é entender se existe uma correlação direta entre essas duas variáveis, ou seja, se um aumento no tempo de voo resulta consistentemente em um maior consumo de combustível.
#
# ### Metodologia:
# - Dados Utilizados: Serão analisados dados de **4000** simulações de voo, onde `time_of_flight_blue` representa a duração total do voo (em segundos) e `fuel_consumed_blue` indica a quantidade de combustível consumida (em libras).
# - Análise Estatística: Aplicar métodos estatísticos para avaliar a relação entre as duas variáveis. Isso inclue a realização de uma análise de regressão linear, cálculo do coeficiente de correlação, ou outros métodos estatísticos relevantes.
# - Visualização de Dados: Utilizar gráficos (como gráficos de dispersão) para visualizar a relação entre tempo de voo e consumo de combustível, facilitando a interpretação dos resultados.
#
# ### Hipóteses:
# A hipótese principal é que existe uma correlação positiva entre o tempo de voo e o consumo de combustível, significando que quanto maior o tempo de voo, maior o consumo de combustível.
#
# ### Resultados Esperados:
# Os resultados podem ser úteis para o planejamento de rotas aéreas mais eficientes em termos de consumo de combustível, e para aprimorar modelos de previsão de consumo de combustível em simulações aeronáuticas.
#
# ### Aplicações Potenciais:
# Os resultados podem ser úteis para treinamento em simuladores de voo, planejamento de rotas aéreas mais eficientes em termos de combustível, e para aprimorar modelos de previsão de consumo de combustível em simulações aeronáuticas.

# %% [markdown]
# #### Data leak intencional, com o intuito de criar um Case de classificação. Asuma que a nfomação do cluster seja obtida de observação factual

# %%
df_nav_class = df_nav.copy()
df_nav_class['Cluster'] = clusters

# %%
# plt.style.use('seaborn-darkgrid')  # Usa um estilo de fundo do Seaborn
# plt.figure(figsize=(10, 6))  # Tamanho do gráfico

class_counts = df_nav_class['Cluster'].value_counts().sort_index()

bars = plt.bar(class_counts.index, class_counts.values, color='skyblue', edgecolor='black')

plt.title('Balanceamento das Classes', fontsize=16, fontweight='bold')
plt.xlabel('Classes', fontsize=14)
plt.ylabel('Número de Instâncias', fontsize=14)

plt.xticks(class_counts.index, fontsize=12)
plt.yticks(fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.7)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, int(yval), ha='center', va='bottom', fontsize=12)

plt.tight_layout()
plt.show()

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

sm = SMOTE(random_state=42)
X = df_nav_class.drop('Cluster', axis=1)
y = df_nav_class['Cluster']

X_res, y_res = sm.fit_resample(X, y)

# Se precisar, converta de volta para DataFrame pandas
df_nav_class = pd.DataFrame(X_res, columns=X.columns)
df_nav_class['Cluster'] = y_res

# %%
# plt.style.use('seaborn-darkgrid')  # Usa um estilo de fundo do Seaborn
# plt.figure(figsize=(10, 6))  # Tamanho do gráfico

class_counts = df_nav_class['Cluster'].value_counts().sort_index()

bars = plt.bar(class_counts.index, class_counts.values, color='skyblue', edgecolor='black')

plt.title('Balanceamento das Classes', fontsize=16, fontweight='bold')
plt.xlabel('Classes', fontsize=14)
plt.ylabel('Número de Instâncias', fontsize=14)

plt.xticks(class_counts.index, fontsize=12)
plt.yticks(fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.7)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, int(yval), ha='center', va='bottom', fontsize=12)

plt.tight_layout()
plt.show()

# %%
sample_nav_class = df_nav_class.sample(10)
df_nav_class = df_nav_class.loc[~df_nav_class.index.isin(sample_nav_class.index)]

# %% [markdown]
# #### Rede Neural

# %%
nn_nav_class = asapy.NeuralNetwork(target="Cluster", name='demo_nn_nav_class', seed=25)

# %%
nn_nav_class.build(
    df_nav_class,
    task='classification',
    max_cat_nunique = 10,
    split_size = (0.7, 0.15, 0.15),
    info=True,
    patience_early_stopping = 20,
    patience_reduceLR = 4,
    metrics=['auc', 'precision', 'recall', 'accuracy'] 
)
# Out:
#                 Task: classification
#
#                 Total of registers: 4562
#                 Total of valid registers: 4562
#                 Total of invalid registers: 0
#
#                 Total of training registers: 3193
#                 Total of validation registers: 685
#                 Total of test registers: 684
#
#                 Features before preprocessing: 3
#                 Features after preprocessing: 3
#
#                 Numerical Features: ['speed', 'altitude', 'fuel_consumed']
#                 Categorical Features: []
#                 Categorical Features removed due to high cardinality: []
#
#                 Target: ['Cluster']
#             	Cardinality (Target): 4

# %%
nn_nav_class.hyperparameter_optimization(
    n_trials=10,
    num_folds=5,
    info=True,
    search_space_dropout = [0.0, 0.5],
    search_space_layers = [2, 3, 4],
    search_space_batch_size = [32, 64],
    search_space_optimizer = ['Adam']
)
# Out:
# <style type="text/css">
# #T_a7a03 th {
#   text-align: center;
# }
# </style>
# <table id="T_a7a03">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7a03_level0_col0" class="col_heading level0 col0" colspan="8">Categorical Crossentropy</th>
#       <th id="T_a7a03_level0_col8" class="col_heading level0 col8" colspan="4">Hyperparameters</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_a7a03_level1_col0" class="col_heading level1 col0" >Trial (nº)</th>
#       <th id="T_a7a03_level1_col1" class="col_heading level1 col1" >Fold nº 1</th>
#       <th id="T_a7a03_level1_col2" class="col_heading level1 col2" >Fold nº 2</th>
#       <th id="T_a7a03_level1_col3" class="col_heading level1 col3" >Fold nº 3</th>
#       <th id="T_a7a03_level1_col4" class="col_heading level1 col4" >Fold nº 4</th>
#       <th id="T_a7a03_level1_col5" class="col_heading level1 col5" >Fold nº 5</th>
#       <th id="T_a7a03_level1_col6" class="col_heading level1 col6" >Folds std</th>
#       <th id="T_a7a03_level1_col7" class="col_heading level1 col7" >Folds mean</th>
#       <th id="T_a7a03_level1_col8" class="col_heading level1 col8" >params_batch_size</th>
#       <th id="T_a7a03_level1_col9" class="col_heading level1 col9" >params_dropout</th>
#       <th id="T_a7a03_level1_col10" class="col_heading level1 col10" >params_layers</th>
#       <th id="T_a7a03_level1_col11" class="col_heading level1 col11" >params_optimizer</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranking</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7a03_level0_row0" class="row_heading level0 row0" >1º</th>
#       <td id="T_a7a03_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_a7a03_row0_col1" class="data row0 col1" >0.138632</td>
#       <td id="T_a7a03_row0_col2" class="data row0 col2" >0.138337</td>
#       <td id="T_a7a03_row0_col3" class="data row0 col3" >0.131037</td>
#       <td id="T_a7a03_row0_col4" class="data row0 col4" >0.116854</td>
#       <td id="T_a7a03_row0_col5" class="data row0 col5" >0.104517</td>
#       <td id="T_a7a03_row0_col6" class="data row0 col6" >0.014851</td>
#       <td id="T_a7a03_row0_col7" class="data row0 col7" >0.125876</td>
#       <td id="T_a7a03_row0_col8" class="data row0 col8" >32</td>
#       <td id="T_a7a03_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_a7a03_row0_col10" class="data row0 col10" >3</td>
#       <td id="T_a7a03_row0_col11" class="data row0 col11" >Adam</td>
#     </tr>
#     <tr>
#       <th id="T_a7a03_level0_row1" class="row_heading level0 row1" >2º</th>
#       <td id="T_a7a03_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_a7a03_row1_col1" class="data row1 col1" >0.112659</td>
#       <td id="T_a7a03_row1_col2" class="data row1 col2" >0.116949</td>
#       <td id="T_a7a03_row1_col3" class="data row1 col3" >0.142627</td>
#       <td id="T_a7a03_row1_col4" class="data row1 col4" >0.136882</td>
#       <td id="T_a7a03_row1_col5" class="data row1 col5" >0.130572</td>
#       <td id="T_a7a03_row1_col6" class="data row1 col6" >0.012815</td>
#       <td id="T_a7a03_row1_col7" class="data row1 col7" >0.127938</td>
#       <td id="T_a7a03_row1_col8" class="data row1 col8" >32</td>
#       <td id="T_a7a03_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_a7a03_row1_col10" class="data row1 col10" >2</td>
#       <td id="T_a7a03_row1_col11" class="data row1 col11" >Adam</td>
#     </tr>
#     <tr>
#       <th id="T_a7a03_level0_row2" class="row_heading level0 row2" >3º</th>
#       <td id="T_a7a03_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_a7a03_row2_col1" class="data row2 col1" >0.122881</td>
#       <td id="T_a7a03_row2_col2" class="data row2 col2" >0.149368</td>
#       <td id="T_a7a03_row2_col3" class="data row2 col3" >0.094688</td>
#       <td id="T_a7a03_row2_col4" class="data row2 col4" >0.134165</td>
#       <td id="T_a7a03_row2_col5" class="data row2 col5" >0.150937</td>
#       <td id="T_a7a03_row2_col6" class="data row2 col6" >0.023063</td>
#       <td id="T_a7a03_row2_col7" class="data row2 col7" >0.130408</td>
#       <td id="T_a7a03_row2_col8" class="data row2 col8" >32</td>
#       <td id="T_a7a03_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_a7a03_row2_col10" class="data row2 col10" >2</td>
#       <td id="T_a7a03_row2_col11" class="data row2 col11" >Adam</td>
#     </tr>
#     <tr>
#       <th id="T_a7a03_level0_row3" class="row_heading level0 row3" >4º</th>
#       <td id="T_a7a03_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_a7a03_row3_col1" class="data row3 col1" >0.815377</td>
#       <td id="T_a7a03_row3_col2" class="data row3 col2" >0.909861</td>
#       <td id="T_a7a03_row3_col3" class="data row3 col3" >0.799482</td>
#       <td id="T_a7a03_row3_col4" class="data row3 col4" >0.739479</td>
#       <td id="T_a7a03_row3_col5" class="data row3 col5" >0.741408</td>
#       <td id="T_a7a03_row3_col6" class="data row3 col6" >0.069634</td>
#       <td id="T_a7a03_row3_col7" class="data row3 col7" >0.801121</td>
#       <td id="T_a7a03_row3_col8" class="data row3 col8" >32</td>
#       <td id="T_a7a03_row3_col9" class="data row3 col9" >0.500000</td>
#       <td id="T_a7a03_row3_col10" class="data row3 col10" >2</td>
#       <td id="T_a7a03_row3_col11" class="data row3 col11" >Adam</td>
#     </tr>
#     <tr>
#       <th id="T_a7a03_level0_row4" class="row_heading level0 row4" >5º</th>
#       <td id="T_a7a03_row4_col0" class="data row4 col0" >9</td>
#       <td id="T_a7a03_row4_col1" class="data row4 col1" >0.769752</td>
#       <td id="T_a7a03_row4_col2" class="data row4 col2" >0.813443</td>
#       <td id="T_a7a03_row4_col3" class="data row4 col3" >0.803318</td>
#       <td id="T_a7a03_row4_col4" class="data row4 col4" >0.877015</td>
#       <td id="T_a7a03_row4_col5" class="data row4 col5" >0.878817</td>
#       <td id="T_a7a03_row4_col6" class="data row4 col6" >0.047952</td>
#       <td id="T_a7a03_row4_col7" class="data row4 col7" >0.828469</td>
#       <td id="T_a7a03_row4_col8" class="data row4 col8" >64</td>
#       <td id="T_a7a03_row4_col9" class="data row4 col9" >0.500000</td>
#       <td id="T_a7a03_row4_col10" class="data row4 col10" >2</td>
#       <td id="T_a7a03_row4_col11" class="data row4 col11" >Adam</td>
#     </tr>
#     <tr>
#       <th id="T_a7a03_level0_row5" class="row_heading level0 row5" >6º</th>
#       <td id="T_a7a03_row5_col0" class="data row5 col0" >7</td>
#       <td id="T_a7a03_row5_col1" class="data row5 col1" >0.810521</td>
#       <td id="T_a7a03_row5_col2" class="data row5 col2" >0.780235</td>
#       <td id="T_a7a03_row5_col3" class="data row5 col3" >0.725417</td>
#       <td id="T_a7a03_row5_col4" class="data row5 col4" >0.959235</td>
#       <td id="T_a7a03_row5_col5" class="data row5 col5" >0.963715</td>
#       <td id="T_a7a03_row5_col6" class="data row5 col6" >0.108151</td>
#       <td id="T_a7a03_row5_col7" class="data row5 col7" >0.847825</td>
#       <td id="T_a7a03_row5_col8" class="data row5 col8" >64</td>
#       <td id="T_a7a03_row5_col9" class="data row5 col9" >0.500000</td>
#       <td id="T_a7a03_row5_col10" class="data row5 col10" >2</td>
#       <td id="T_a7a03_row5_col11" class="data row5 col11" >Adam</td>
#     </tr>
#     <tr>
#       <th id="T_a7a03_level0_row6" class="row_heading level0 row6" >7º</th>
#       <td id="T_a7a03_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_a7a03_row6_col1" class="data row6 col1" >0.904065</td>
#       <td id="T_a7a03_row6_col2" class="data row6 col2" >0.824591</td>
#       <td id="T_a7a03_row6_col3" class="data row6 col3" >0.953633</td>
#       <td id="T_a

# %%
history_nn_nav_class = nn_nav_class.fit(return_history=True, graph=True, graph_save_extension='png', verbose=0)

# %%
pred_nn_nav_class = nn_nav_class.predict(sample_nav_class, verbose=0)
# Out:
# Inference time: 57.75 milliseconds (10 register(s))

# %%
pred_nn_nav_class
# Out:
#            speed      altitude  fuel_consumed  Cluster  \
# 265   406.470000  30895.950000     984.832925        2
# 3781  353.270000  11832.060000    1238.786508        3
# 2520  492.650000  18755.670000    1206.033515        0
# 605   547.960000  20261.770000    1321.522223        0
# 3441  357.250000  27086.610000     985.816667        2
# 4212  500.604456  10753.268929    1630.381871        0
# 3810  399.250000  31707.680000    1020.607137        2
# 4512  394.428994  17959.584869    1037.291781        3
# 4468  414.737309  13885.404704    1192.159260        3
# 4446  432.152798  20914.078728    1049.138111        3
#
#       Cluster (NN prediction)
# 265                         2
# 3781                        3
# 2520                        0
# 605                         0
# 3441                        2
# 4212                        0
# 3810                        2
# 4512                        3
# 4468                        3
# 4446                        3

# %% [markdown]
# #### XG Boost

# %%
xgb_nav_class = asapy.XgBoost(target="Cluster", name='demo_xgb_nav_class', seed=25)

# %%
xgb_nav_class.build(
    df_nav_class,
    task='classification',
    max_cat_nunique = 10,
    split_size = (0.7, 0.15, 0.15),
    info=True,
    patience_early_stopping = 20
)
# Out:
#                 Task: classification
#
#                 Total of registers: 4562
#                 Total of valid registers: 4562
#                 Total of invalid registers: 0
#
#                 Total of training registers: 3193
#                 Total of validation registers: 685
#                 Total of test registers: 684
#
#                 Features before preprocessing: 3
#                 Features after preprocessing: 3
#
#                 Numerical Features: ['speed', 'altitude', 'fuel_consumed']
#                 Categorical Features: []
#                 Categorical Features removed due to high cardinality: []
#
#                 Target: ['Cluster']
#             	Cardinality (Target): 4

# %%
xgb_nav_class.hyperparameter_optimization(
    n_trials=10,
    num_folds=5,
    info=True,
    search_space_tree_method = ['auto'],
    search_space_booster = ['gbtree', 'gblinear', 'dart'],
    search_space_learning_rate = [0.2, 0.3],
    search_space_min_split_loss = [0],
    search_space_max_depth = [5, 6, 7],
    search_space_min_child_weight = [1],
    search_space_max_delta_step = [0],
    search_space_subsample = [1],
    search_space_sampling_method = ['uniform'],
    search_space_colsample_bytree = [1],
    search_space_colsample_bylevel = [1],
    search_space_colsample_bynode = [1],
    search_space_reg_lambda = [1],
    search_space_reg_alpha = [0],
    search_space_scale_pos_weight = [1],
    search_space_grow_policy = ['depthwise'],
    search_space_max_leaves = [0],
    search_space_max_bin = [256, 512],
    search_space_num_parallel_tree = [1]
)
# Out:
# <style type="text/css">
# #T_a0169 th {
#   text-align: center;
# }
# </style>
# <table id="T_a0169">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0169_level0_col0" class="col_heading level0 col0" colspan="8">Categorical Crossentropy</th>
#       <th id="T_a0169_level0_col8" class="col_heading level0 col8" colspan="19">Hyperparameters</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_a0169_level1_col0" class="col_heading level1 col0" >Trial (nº)</th>
#       <th id="T_a0169_level1_col1" class="col_heading level1 col1" >Fold nº 1</th>
#       <th id="T_a0169_level1_col2" class="col_heading level1 col2" >Fold nº 2</th>
#       <th id="T_a0169_level1_col3" class="col_heading level1 col3" >Fold nº 3</th>
#       <th id="T_a0169_level1_col4" class="col_heading level1 col4" >Fold nº 4</th>
#       <th id="T_a0169_level1_col5" class="col_heading level1 col5" >Fold nº 5</th>
#       <th id="T_a0169_level1_col6" class="col_heading level1 col6" >Folds std</th>
#       <th id="T_a0169_level1_col7" class="col_heading level1 col7" >Folds mean</th>
#       <th id="T_a0169_level1_col8" class="col_heading level1 col8" >params_booster</th>
#       <th id="T_a0169_level1_col9" class="col_heading level1 col9" >params_colsample_bylevel</th>
#       <th id="T_a0169_level1_col10" class="col_heading level1 col10" >params_colsample_bynode</th>
#       <th id="T_a0169_level1_col11" class="col_heading level1 col11" >params_colsample_bytree</th>
#       <th id="T_a0169_level1_col12" class="col_heading level1 col12" >params_grow_policy</th>
#       <th id="T_a0169_level1_col13" class="col_heading level1 col13" >params_learning_rate</th>
#       <th id="T_a0169_level1_col14" class="col_heading level1 col14" >params_max_bin</th>
#       <th id="T_a0169_level1_col15" class="col_heading level1 col15" >params_max_delta_step</th>
#       <th id="T_a0169_level1_col16" class="col_heading level1 col16" >params_max_depth</th>
#       <th id="T_a0169_level1_col17" class="col_heading level1 col17" >params_max_leaves</th>
#       <th id="T_a0169_level1_col18" class="col_heading level1 col18" >params_min_child_weight</th>
#       <th id="T_a0169_level1_col19" class="col_heading level1 col19" >params_min_split_loss</th>
#       <th id="T_a0169_level1_col20" class="col_heading level1 col20" >params_num_parallel_tree</th>
#       <th id="T_a0169_level1_col21" class="col_heading level1 col21" >params_reg_alpha</th>
#       <th id="T_a0169_level1_col22" class="col_heading level1 col22" >params_reg_lambda</th>
#       <th id="T_a0169_level1_col23" class="col_heading level1 col23" >params_sampling_method</th>
#       <th id="T_a0169_level1_col24" class="col_heading level1 col24" >params_scale_pos_weight</th>
#       <th id="T_a0169_level1_col25" class="col_heading level1 col25" >params_subsample</th>
#       <th id="T_a0169_level1_col26" class="col_heading level1 col26" >params_tree_method</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranking</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0169_level0_row0" class="row_heading level0 row0" >1º</th>
#       <td id="T_a0169_row0_col0" class="data row0 col0" >7</td>
#       <td id="T_a0169_row0_col1" class="data row0 col1" >0.031905</td>
#       <td id="T_a0169_row0_col2" class="data row0 col2" >0.044551</td>
#       <td id="T_a0169_row0_col3" class="data row0 col3" >0.017841</td>
#       <td id="T_a0169_row0_col4" class="data row0 col4" >0.006670</td>
#       <td id="T_a0169_row0_col5" class="data row0 col5" >0.015973</td>
#       <td id="T_a0169_row0_col6" class="data row0 col6" >0.014880</td>
#       <td id="T_a0169_row0_col7" class="data row0 col7" >0.023388</td>
#       <td id="T_a0169_row0_col8" class="data row0 col8" >gbtree</td>
#       <td id="T_a0169_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_a0169_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_a0169_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_a0169_row0_col12" class="data row0 col12" >depthwise</td>
#       <td id="T_a0169_row0_col13" class="data row0 col13" >0.300000</td>
#       <td id="T_a0169_row0_col14" class="data row0 col14" >512</td>
#       <td id="T_a0169_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_a0169_row0_col16" class="data row0 col16" >6</td>
#       <td id="T_a0169_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_a0169_row0_col18" class="data row0 col18" >1</td>
#       <td id="T_a0169_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_a0169_row0_col20" class="data row0 col20" >1</td>
#       <td id="T_a0169_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_a0169_row0_col22" class="data row0 col22" >1</td>
#       <td id="T_a0169_row0_col23" class="data row0 col23" >uniform</td>
#       <td id="T_a0169_row0_col24" class="data row0 col24" >1</td>
#       <td id="T_a0169_row0_col25" class="data row0 col25" >1</td>
#       <td id="T_a0169_row0_col26" class="data row0 col26" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_a0169_level0_row1" class="row_heading level0 row1" >2º</th>
#       <td id="T_a0169_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_a0169_row1_col1" class="data row1 col1" >0.015031</td>
#       <td id="T_a0169_row1_col2" class="data row1 col2" >0.027817</td>
#       <td id="T_a0169_row1_col3" class="data row1 col3" >0.018427</td>
#       <td id="T_a0169_row1_col4" class="data row1 col4" >0.035785</td>
#       <td id="T_a0169_row1_col5" class="data row1 col5" >0.022082</td>
#       <td id="T_a0169_row1_col6" class="data row1 col6" >0.008193</td>
#       <td id="T_a0169_row1_col7" class="data row1 col7" >0.023829</td>
#       <td id="T_a0169_row1_col8" class="data row1 col8" >dart</td>
#       <td id="T_a0169_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_a0169_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_a0169_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_a0169_row1_col12" class="data row1 col12" >depthwise</td>
#       <td id="T_a0169_row1_col13" class="data row1 col13" >0.200000</td>
#       <td id="T_a0169_row1_col14" class="data row1 col14" >256</td>
#       <td id="T_a0169_row1_col15" class="data row1 col15" >0</td>
#       <td id="T_a0169_row1_col16" class="data row1 col16" >7</td>
#       <td id="T_a0169_row1_col17" class="data row1 col17" >0</td>
#       <td id="T_a0169_row1_col18" class="data row1 col18" >1</td>
#       <td id="T_a0169_row1_col19" class="data row1 col19" >0</td>
#       <td id="T_a0169_row1_col20" class="data row1 col20" >1</td>
#       <td id="T_a0169_row1_col21" class="data row1 col21" >0</td>
#       <td id="T_a0169_row1_col22" class="data row1 col22" >1</td>
#       <td id="T_a0169_row1_col23" class="data row1 col23" >uniform</td>
#       <td id="T_a0169_row1_col24" class="data row1 col24" >1</td>
#       <td id="T_a0169_row1_col25" class="data row1 col25" >1</td>
#       <td id="T_a0169_row1_col26" class="data row1 c

# %%
history_xgb_nav_class = xgb_nav_class.fit(return_history=True, graph=True, graph_save_extension='png', verbose=0)

# %%
pred_xgb_nav_class = xgb_nav_class.predict(sample_nav_class)
# Out:
# Inference time: 7.42 milliseconds (10 register(s))

# %%
pred_xgb_nav_class
# Out:
#            speed      altitude  fuel_consumed  Cluster  \
# 265   406.470000  30895.950000     984.832925        2
# 3781  353.270000  11832.060000    1238.786508        3
# 2520  492.650000  18755.670000    1206.033515        0
# 605   547.960000  20261.770000    1321.522223        0
# 3441  357.250000  27086.610000     985.816667        2
# 4212  500.604456  10753.268929    1630.381871        0
# 3810  399.250000  31707.680000    1020.607137        2
# 4512  394.428994  17959.584869    1037.291781        3
# 4468  414.737309  13885.404704    1192.159260        3
# 4446  432.152798  20914.078728    1049.138111        3
#
#      Cluster (XGB prediction)
# 265                         2
# 3781                        3
# 2520                        0
# 605                         0
# 3441                        2
# 4212                        0
# 3810                        2
# 4512                        3
# 4468                        3
# 4446                        3
